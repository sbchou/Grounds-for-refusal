# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
import inspect
from datetime import datetime
import seaborn as sns
import glob
from os.path import basename
sns.set_context('poster')
import re
import csv

# %% [markdown]
# ### Load and merge spreadsheets, taken from State Dept. site

# %%
df = pandas.read_excel('../data/spreadsheets/FY16AnnualReport-TableXX.xlsx')

# %%
df.head()
# Out:
#        212(a)(1)(A)(i)                     Communicable Disease  Unnamed: 2  \
# 0     212(a)(1)(A)(ii)  Immigrant lacking required vaccinations         NaN
# 1    212(a)(1)(A)(iii)              Physical or mental disorder         NaN
# 2     212(a)(1)(A)(iv)                    Drug Abuser or Addict         NaN
# 3   212(a)(2)(A)(i)(I)          Crime Involving Moral Turpitude         NaN
# 4  212(a)(2)(A)(i)(II)           Controlled Substance Violators         NaN
#
#     951 Unnamed: 4  669  Unnamed: 6 Unnamed: 7    34 Unnamed: 9     4
# 0    73        NaN   40         NaN        NaN     -        NaN     -
# 1   497        NaN  109         NaN        NaN   259        NaN    36
# 2  1569        NaN  838         NaN        NaN   117        NaN    21
# 3  1794        NaN  359         NaN        NaN  9522        NaN  4834
# 4   664        NaN   55         NaN        NaN  6494        NaN  3344

# %%
df.dropna(how='all')
# Out:
#                                            Unnamed: 0  \
# 0                                     212(a)(1)(A)(i)
# 1                                    212(a)(1)(A)(ii)
# 2                                   212(a)(1)(A)(iii)
# 3                                    212(a)(1)(A)(iv)
# 4                                  212(a)(2)(A)(i)(I)
# 5                                 212(a)(2)(A)(i)(II)
# 6                                        212(a)(2)(B)
# 7                                     212(a)(2)(C)(i)
# 8                                    212(a)(2)(C)(ii)
# 9                                     212(a)(2)(D)(i)
# 10                                   212(a)(2)(D)(ii)
# 11                                  212(a)(2)(D)(iii)
# 12                                       212(a)(2)(E)
# 13                                       212(a)(2)(G)
# 14                                       212(a)(2)(H)
# 15                                       212(a)(2)(I)
# ...

# %%
df = pandas.read_excel('../data/spreadsheets/FY16AnnualReport-TableXX.xlsx', names=['act','offense','imm_found','imm_overcome','nonimm_found','nonimm_overcome',"","","","",""])

# %%
df.head()
# Out:
#                  test1                                     test test test  \
# 0     212(a)(1)(A)(ii)  Immigrant lacking required vaccinations   94   87
# 1    212(a)(1)(A)(iii)              Physical or mental disorder  140   44
# 2     212(a)(1)(A)(iv)                    Drug Abuser or Addict  743    9
# 3   212(a)(2)(A)(i)(I)          Crime Involving Moral Turpitude  595  201
# 4  212(a)(2)(A)(i)(II)           Controlled Substance Violators  384   39
#
#   test  test test  test
# 0  NaN     -  NaN     -
# 1  NaN     8  NaN     4
# 2  NaN    46  NaN    12
# 3  NaN  2855  NaN  1687
# 4  NaN  1370  NaN   785
